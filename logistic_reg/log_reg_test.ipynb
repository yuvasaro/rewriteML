# %%
import numpy as np
from log_reg import f_wb, zscore_normalize, compute_cost, compute_gradient, gradient_descent, plot_J_hist

np.set_printoptions(precision=3)

# %%
X_train = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_train = np.array([0, 0, 0, 1, 1, 1])

# %%
# gradient descent settings
n = X_train.shape[1]
w_in = np.zeros((n,))
b_in = 0
alpha = 1e-1
lambda_ = 0.001

# run gradient descent
w_final, b_final, J_hist = gradient_descent(
    X_train, 
    y_train, 
    w_in, 
    b_in, 
    alpha, 
    lambda_, 
    model=f_wb, 
    cost_func=compute_cost, 
    grad_func=compute_gradient, 
    num_iter=10000
)

print(f"Results: w = {w_final}, b = {b_final:0.3e}")
# Out:
# Iteration:  1000, w: [2.301 2.073], b: -5.899e+00, Cost: 1.604e-01
# Iteration:  2000, w: [3.144 2.93 ], b: -8.286e+00, Cost: 8.674e-02
# Iteration:  3000, w: [3.663 3.453], b: -9.739e+00, Cost: 5.985e-02
# Iteration:  4000, w: [4.034 3.827], b: -1.078e+01, Cost: 4.625e-02
# Iteration:  5000, w: [4.322 4.115], b: -1.158e+01, Cost: 3.813e-02
# Iteration:  6000, w: [4.555 4.35 ], b: -1.223e+01, Cost: 3.278e-02
# Iteration:  7000, w: [4.751 4.546], b: -1.277e+01, Cost: 2.902e-02
# Iteration:  8000, w: [4.919 4.715], b: -1.324e+01, Cost: 2.625e-02
# Iteration:  9000, w: [5.066 4.863], b: -1.365e+01, Cost: 2.413e-02
# Iteration: 10000, w: [5.197 4.993], b: -1.402e+01, Cost: 2.247e-02
# Results: w = [5.197 4.993], b = -1.402e+01

# %%
plot_J_hist(J_hist)
