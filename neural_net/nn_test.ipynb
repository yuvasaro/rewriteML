# %% [markdown]
# Testing my own NeuralNetwork class! (`nn_from_scratch.py`)

# %%
import numpy as np
import matplotlib.pyplot as plt
from nn_from_scratch import NeuralNetwork

# %%
# XOR dataset
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [0]])

nn = NeuralNetwork([2, 2, 1], alpha=0.5)
nn.train(X, y, epochs=20000)
# Out:
# Epoch 2000/20000: cost = 0.0005232035927661217
# Epoch 4000/20000: cost = 0.00023319746519082394
# Epoch 6000/20000: cost = 0.00014822453248775901
# Epoch 8000/20000: cost = 0.00010813049154375222
# Epoch 10000/20000: cost = 8.487247858371089e-05
# Epoch 12000/20000: cost = 6.973276730418338e-05
# Epoch 14000/20000: cost = 5.911185605344846e-05
# Epoch 16000/20000: cost = 5.125925131342778e-05
# Epoch 18000/20000: cost = 4.522535348614963e-05
# Epoch 20000/20000: cost = 4.043944019588526e-05

# %%
np.round(nn.predict(X))
# Out:
# array([[0.],
#        [1.],
#        [1.],
#        [0.]])

# %%
nn.plot_J_hist()
